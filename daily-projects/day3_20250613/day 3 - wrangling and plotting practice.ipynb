# %% [markdown]
# # Day 3 - Banana Index
#
# Today I'm using this dataset [https://github.com/TheEconomist/banana-index-data/tree/master] from the economist, which ranks food sources based on their CO2 equivalent compared to Bananas (banana index).
# Today I'm focusing on  plotting and data wrangling to improve those skills.

# %%
# Libraries
import pandas as pd
import altair as alt

# %%
df_banana = pd.read_csv("bananaindex.csv")

# %%
df_banana
# Out:
#              entity  year  emissions_kg  emissions_1000kcal  \
# 0               Ale  2022      0.488690            0.317338
# 1     Almond butter  2022      0.387011            0.067265
# 2       Almond milk  2022      0.655888            2.222230
# 3           Almonds  2022      0.602368            0.105029
# 4       Apple juice  2022      0.458378            0.955184
# ..              ...   ...           ...                 ...
# 155  Tortilla wraps  2022      0.948584            0.393648
# 156            Tuna  2022     13.075355            9.969608
# 157         Walnuts  2022      2.416308            0.409580
# 158      Watermelon  2022      0.969403            2.464087
# 159         Yoghurt  2022      3.111811            3.986662
#
#      emissions_100g_protein  emissions_100g_fat  land_use_kg  \
# 0                  0.878525            2.424209     0.811485
# 1                  0.207599            0.079103     7.683045
# 2                 13.595512            4.057470     1.370106
# 3                  0.328335            0.119361     8.230927
# 4                 29.152212           19.754980     0.660629
# ..                      ...                 ...          ...
# 155                1.260451            1.658348     2.256113
# 156                4.972586          105.113632     5.521840
# 157                1.725508            0.492456    11.875852
# 158               16.335799           22.110017     1.009878
# 159                8.365670           33.620356     3.209721
#
#      land_use_1000kcal  Land use per 100 grams of protein  \
# 0             0.601152                           1.577687
# 1             1.296870                           3.608433
# 2             2.675063                          12.687839
# 3             1.423376                           4.261040
# 4             1.382839                          43.232158
# ..                 ...                                ...
# 155           0.979229                           2.979443
# 156           4.194251                           2.167108
# 157           1.924057                           7.828816
# 158           2.616771                          17.232334
# 159           4.120987                           8.586253
#
#      Land use per 100 grams of fat  Bananas index (kg)  \
# 0                         3.065766            0.559558
# 1                         1.495297            0.443134
# 2                         4.600530            0.751002
# 3                         1.610136            0.689721
# 4                        26.246743            0.524851
# ..                             ...                 ...
# 155                       4.106024            1.086144
# 156                      44.058029           14.971502
# 157                       2.092320            2.766713
# 158                      22.874311            1.109983
# 159                      34.333541            3.563076
#
#      Bananas index (1000 kcalories)  Bananas index (100g protein)  Chart?  \
# 0                          0.362340                      0.113771    True
# 1                          0.076804                      0.026885    True
# 2                          2.537364                      1.760651    True
# 3                          0.119923                      0.042520    True
# 4                          1.090638                      3.775280    True
# ..                              ...                           ...     ...
# 155                        0.449471                      0.163231    True
# 156                       11.383397                      0.643961    True
# 157                        0.467663                      0.223457    True
# 158                        2.813519                      2.115524    True
# 159                        4.552010                      1.083374    True
#
#      type       Banana values  Unnamed: 16
# 0       1              Per KG     0.873350
# 1       1  Per 1000 kcalories     0.875803
# 2       1    Per 100g protein     7.721869
# 3       1                 NaN          NaN
# 4       1                 NaN          NaN
# ..    ...                 ...          ...
# 155     1                 NaN          NaN
# 156     2                 NaN          NaN
# 157     1                 NaN          NaN
# 158     1                 NaN          NaN
# 159     3                 NaN          NaN
#
# [160 rows x 17 columns]

# %% [markdown]
# Let's hone in on the protein related data in this dataset

# %%
df_protein = df_banana[["entity", "year", "emissions_100g_protein", "Land use per 100 grams of protein", "Bananas index (100g protein)"]]

# %%
df_protein
# Out:
#              entity  year  emissions_100g_protein  \
# 0               Ale  2022                0.878525
# 1     Almond butter  2022                0.207599
# 2       Almond milk  2022               13.595512
# 3           Almonds  2022                0.328335
# 4       Apple juice  2022               29.152212
# ..              ...   ...                     ...
# 155  Tortilla wraps  2022                1.260451
# 156            Tuna  2022                4.972586
# 157         Walnuts  2022                1.725508
# 158      Watermelon  2022               16.335799
# 159         Yoghurt  2022                8.365670
#
#      Land use per 100 grams of protein  Bananas index (100g protein)
# 0                             1.577687                      0.113771
# 1                             3.608433                      0.026885
# 2                            12.687839                      1.760651
# 3                             4.261040                      0.042520
# 4                            43.232158                      3.775280
# ..                                 ...                           ...
# 155                           2.979443                      0.163231
# 156                           2.167108                      0.643961
# 157                           7.828816                      0.223457
# 158                          17.232334                      2.115524
# 159                           8.586253                      1.083374
#
# [160 rows x 5 columns]

# %% [markdown]
# Lets do some descriptive data analysis by doing some plotting.

# %%
# Out:
# alt.Chart(...)

# %% [markdown]
# That not very pretty, let's turn the chart on it's side for readability and sort the values according to emissions

# %%
alt.Chart(df_protein).mark_bar().encode(
    x="entity", y="emissions_100g_protein")
# Out:
# alt.Chart(...)

# %%
# plotting entity and their respective emissions per 100g protein
alt.Chart(df_protein).mark_bar().encode(
    y=alt.Y("entity").sort("-x").title("Type of food"),
    x=alt.X("emissions_100g_protein").title("Emissions per 100g of protein")
)
# Out:
# alt.Chart(...)

# %% [markdown]
# It seems that foods that are high in sugar, fat, or have a high water content (grapes), are emissions heavy relative to their protein content. I would say that a lot of these foods aren't necessarily eaten for their protein content, thus it would be better to include foods with a similar protein percentage of let's say 5%. We are however lacking that data in this analysis.

# %%
# How about land use in relation to emissions per gram of protein?
alt.Chart(df_protein).mark_point().encode(
    y=alt.Y("Land use per 100 grams of protein").sort("-x").title("Land use per 100 grams of protein"),
    x=alt.X("emissions_100g_protein").title("Emissions per 100g of protein"),
    color="entity"
)
# Out:
# alt.Chart(...)

# %% [markdown]
# Here we can see that the foods are mostly bunched together, although there are some outliers with heavy land use or emissions per protein

# %% [markdown]
# Let's filter out the blob and look at the outliers.

# %%
df_outliers = df_protein[df_protein["emissions_100g_protein"] > 20]
df_outliers = df_outliers[df_outliers["Land use per 100 grams of protein"] > 20]

# %%
# How about land use in relation to emissions
alt.Chart(df_outliers).mark_point().encode(
    y=alt.Y("Land use per 100 grams of protein").sort("-x").title("Land use per 100 grams of protein"),
    x=alt.X("emissions_100g_protein").title("Emissions per 100g of protein"),
    color="entity"
)
# Out:
# alt.Chart(...)
