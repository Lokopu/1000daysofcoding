# %% [markdown]
# # Day 5 - Webscraping
#
# Today the goal will be to scrape Rema1000 locations around the country.

# %% [markdown]
# From the Rema1000 website we can see that the div class responsible for the element listing all Danish stores as a `div` with:
# `
# class="grid aspect-square h-auto auto-rows-min grid-cols-1 divide-y overflow-y-auto overflow-x-hidden lg:aspect-auto lg:h-[504px]"
# `

# %% [markdown]
# <div>
# <img src="pictures/stores.png" width="1000"/>
# </div>

# %% [markdown]
# Second we can see that this "root" div has "child" divs for each store with the element being references as `id="store-list__item-329"`

# %% [markdown]
# <div>
# <img src="pictures/address.png" width="1000"/>
# </div>

# %% [markdown]
# Above, we can then see that each indiviual store element has a `h2` header (`class="text-xl font-bold"`) and an `address` (`class="text-base font-medium not-italic"`) element for storing the name of the store and it's address.
#
# With this in place we should be able to scrape all stores from the Rema1000 website and store them.

# %%
# Now lets use Beautifulsoup to scrape the site
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# base information
URL = "https://rema1000.dk/find-butik-og-abningstider"
page = requests.get(URL)

# %%
# Check if we are retrieving the HTML from the site
page.text
# Out:
# '<!DOCTYPE html><html  lang="da" data-capo=""><head><meta charset="utf-8">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<script id="CookieConsent" src="https://policy.app.cookieinformation.com/uc.js" type="text/javascript" data-culture="DA"></script>\n<script type="text/javascript">var _mtm = window._mtm = window._mtm || [];_mtm.push({\'mtm.startTime\': (new Date().getTime()), \'event\': \'mtm.Start\'});(function() {var d=document, g=d.createElement(\'script\'), s=d.getElementsByTagName(\'script\')[0];g.async=true; g.src=\'https://matomo.digital.rema1000.dk/js/container_tZ2kTSpc.js\'; s.parentNode.insertBefore(g,s);})();</script>\n<title>Find butik og åbningstider | REMA 1000</title>\n<link rel="preconnect" href="https://content-images.digital.rema1000.dk">\n<link rel="preconnect" href="https://d15493jtiio2fp.cloudfront.net">\n<script src="https://d15493jtiio2fp.cloudfront.net/shopping-list-web-sdk/rema1000-shopping-list.umd.js" async defer data-hid="12f2af6"></script>\n<script id="CrossStorage" src="/hub.js" type="text/javascript"></script>\n<style type="text/css">:root{--rema-primary-color:#1C4378;--rema-primary-hover-color:#002f61;--rema-secondary-color:#2568EF;--rema-secondary-hover-color:#0053d5;--rema-tertiary-color:#F2F4FC;--rema-tertiary-hover-color:#d8dae2;--rema-cta-color:#2568EF;--rema-cta-hover-color:#0053d5;--rema-cta-foreground-color:#FFF;--rema-cta-foreground-hover-color:#e5e5e5;--rema-footer-background-color:#002A56;}</style>\n<link rel="stylesheet" href="/static/cogf5gyusx41v2z7.css">\n<link rel="stylesheet" href="/static/ggn9rfqlzt7ol1kq.css">\n<link rel="stylesheet" href="/static/cx63yaou6t21kg8p.css">\n<link rel="preload" href="/fonts/UniformRndCond-Regular.ttf" as="font" crossorigin="anonymous">\n<link rel="preload" href="/fonts/UniformRndCond-Medium.ttf" as="font" crossorigin="anonymous">\n<link rel="preload" href="/fonts/UniformRndCond-Bold.ttf" as="font" crossorigin="anonymous">\n<link rel="preload" href="/fonts/UniformRndExCond-Regular.ttf" as="font" crossorigin="anonymous">\n<link rel="preload" href="/fonts/UniformRndExCond-Medium.ttf" as="font" crossorigin="anonymous">\n<link rel="preload" href="/fonts/UniformRndExCond-Bold.ttf" as="font" crossorigin="anonymous">\n<link rel="modulepreload" as="script" crossorigin href="/static/dz24coyrrlosgqab.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/cysyb5rwigqzvkwr.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/gi79z2j8w8kwzqqd.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/lc9wxyb012vr5dpm.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/n0x7xz7lyhe9nna3.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/mdz7sfgeplhb644n.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/n822daf9k3nwxsf3.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/dlys7qi2xadye93m.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/d0dy13oodkae1fb8.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/mlwwokul4jpu0vqx.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/dz6ab11bxfh0bkmt.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/ityv8xy005n78lvv.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/ggnmcysfer8c2ibr.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/cbuflzvvxln4xjug.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/gbzwgoeaqxay3mf7.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/ir9jstdxyjmg1vvf.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/ive6kcilqrwcqyot.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/c2udfsfv761vxrwd.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/o1sw1tvy5xwp6igx.js">\n<link rel="modulepreload" as="script" crossorigin href="/static/ceduykpk22t3rihi.js">\n<lin ...

# %% [markdown]
# It works, now lets retrieve the store objects

# %%
# Parse
soup = BeautifulSoup(page.content, "html.parser")

# Retrieve all store elements
stores = soup.find_all("div", class_="py-2 text-rema-evening")

# Create list for storing store data
data_stores = []

# Loop through all stores and retrieve individual store names and addresses
for store in stores:
    name = store.find("h2", class_="text-xl font-bold")
    address = store.find("address", class_="text-base font-medium not-italic")

    # Add dictionaries to list
    data_stores.append({"name":name.text, "address":address.text})

# Add data to dataframe
df_stores = pd.DataFrame(data_stores)

# Display dataframe
df_stores
# Out:
#                          name  \
# 0    Aabenraa, Cimbria Parken
# 1           Aabenraa, Nyløkke
# 2         Aabenraa, Rugkobbel
# 3                     Aabybro
# 4    Aalborg C, Budolfi Plads
# ..                        ...
# 425                    Åbyhøj
# 426                     Ålbæk
# 427                    Årslev
# 428                     Ølgod
# 429                  Ølstykke
#
#                                                address
# 0      Reberbanen 7 st., Cimbria Parken, 6200 Aabenraa
# 1                             Nyløkke 3, 6200 Aabenraa
# 2    Farversmøllevej 2-4, Rugkobbelcentret, 6200 Aa...
# 3                    Aabybro Centret 2 C, 9440 Aabybro
# 4                         Vingårdsgade 6, 9000 Aalborg
# ..                                                 ...
# 425                      Silkeborgvej 261, 8230 Åbyhøj
# 426                      Søndre Havnevej 4, 9982 Ålbæk
# 427                          Overvejen 79, 5792 Årslev
# 428                            Østerbro 24, 6870 Ølgod
# 429                      Rådhus Allé 22, 3650 Ølstykke
#
# [430 rows x 2 columns]

# %% [markdown]
# Thus we've scraped the name and address of all Rema1000s across Denmark
